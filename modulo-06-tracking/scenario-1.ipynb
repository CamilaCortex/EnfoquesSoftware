# %% [markdown]
# ## Cómo crear y usar un kernel de Jupyter a partir de un entorno virtual creado con `uv`
#
# Sigue estos pasos para que tu entorno virtual (creado con `uv`) pueda ser seleccionado y usado como kernel en Jupyter Notebook o Jupyter Lab:
#
# 1. **Activa tu entorno virtual**
#    ```bash
#    source .venv/bin/activate
#
# (Reemplaza .venv por el nombre de tu entorno si es diferente)
#
# 2. Instala ipykernel en el entorno
#    ```bash
#    pip install ipykernel
#
# 3. Crea y registra el kernel para Jupyter
#    ```bash
#    python -m ipykernel install --user --name mlops-udm --display-name "mlops udm"
#
# * Pon el nombre que deseas, en este caso usaré mlops-udm pero puedes asignar el que desees.
#
# * Puedes cambiar mlops-udm y "mlops udm" por el nombre que prefieras para identificar tu kernel.
#
# ----> Ve al menú superior: Kernel > Cambiar kernel... y elige "mlops udm".
# _______

# %% [markdown]
# ## Escenario 1: Un cientifico de datos participando de una competición en kaggle
#
# MLflow setup:
# * Tracking server: no
# * Backend store: sistema de archivos local
# * Artifacts store: sistema de archivos local
#
# Usando MLFlow Ui podemos revisar los resultados

# %%
import os

import mlflow
import pandas as pd

# %%
MLFLOW_ALLOW_FILE_STORE=True

# %% [markdown]
# En este escenario **no levantamos un Tracking Server**. MLflow guarda todo en un *file store* local.
#
# Para que sea reproducible (y no dependa de rutas absolutas), fijamos el tracking URI a una carpeta `./mlruns` dentro del directorio `scenarios/`.

# %%
tracking_dir = os.path.join(os.getcwd(), "mlruns")
mlflow.set_tracking_uri("sqlite:///mlflow.db")

print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///Users/mdurango/Downloads/proyectos/machine-learning-zoomcamp/modulo-06-tracking/mlruns'

# %% [markdown]
# Define la ubicación donde se almacenarán los metadatos de los experimentos.
#
# En este caso, apunta a la carpeta `mlruns/` dentro de `scenarios/` (file store local).

# %%
mlflow.search_experiments()
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mlflow.search_experiments()
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:2298, in search_experiments(view_type, max_results, filter_string, order_by)
#    2289 def pagination_wrapper_func(number_to_get, next_page_token):
#    2290     return MlflowClient().search_experiments(
#    2291         view_type=view_type,
#    2292         max_results=number_to_get,
#    (...)   2295         page_token=next_page_token,
#    2296     )
# -> 2298 return get_results_from_paginated_fn(
#    2299     pagination_wrapper_func,
#    2300     SEARCH_MAX_RESULTS_DEFAULT,
#    2301     max_results,
#    2302 )
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/utils/__init__.py:255, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     253     page_results = paginated_fn(num_to_get, next_page_token)
#     254 else:
# --> 255     page_results = paginated_fn(max_results_per_page, next_page_token)
#     256 all_results.extend(page_results)
#     257 if hasattr(page_results, "token") and page_results.token:
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:2290, in search_experiments.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#    2289 def pagination_wrapper_func(number_to_get, next_page_token):
# -> 2290     return MlflowClient().search_experiments(
#    2291         view_type=view_type,
#    2292         max_results=number_to_get,
#    2293         filter_string=filter_string,
#    2294         order_by=order_by,
#    2295         page_token=next_page_token,
#    2296     )
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:248, in MlflowClient.__init__(self, tracking_uri, registry_uri, workspace_store_uri)
#     246 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     247 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 248 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#     249 self._workspace_store_uri = workspace_utils.resolve_workspace_store_uri(
#     250     workspace_store_uri, tracking_uri=final_tracking_uri
#     251 )
#     252 self._tracing_client = TracingClient(final_tracking_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:99, in TrackingServiceClient.__init__(self, tracking_uri)
#      94 self.tracking_uri = tracking_uri
#      95 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      96 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      97 # property method to ensure that the client is serializable, even if the store is not
#      98 # self.store
# ---> 99 self.store
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:103, in TrackingServiceClient.store(self)
#     101 @property
#     102 def store(self):
# --> 103     return utils._get_store(self.tracking_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/utils.py:270, in _get_store(store_uri, artifact_uri)
#     269 def _get_store(store_uri=None, artifact_uri=None):
# --> 270     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/utils.py:184, in _get_file_store(store_uri, **_)
#     181 def _get_file_store(store_uri, **_):
#     182     from mlflow.store.tracking.file_store import FileStore
# --> 184     return FileStore(store_uri, store_uri)
#
# File ~/Downloads/proyectos/machine-learning-zoomcamp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/file_store.py:225, in FileStore.__init__(self, root_directory, artifact_root_uri)
#     223 super().__init__()
#     224 if not MLFLOW_ALLOW_FILE_STORE.get():
# --> 225     raise MlflowException(
#     226         "The filesystem tracking backend (e.g., './mlruns') is in maintenance mode "
#     227         "and will not receive further updates. Please migrate to a "
#     228         "database backend (e.g., 'sqlite:///mlflow.db') to access the latest MLflow "
#     229         "features. The `mlflow migrate-filestore` tool migrates your existing data "
#     230         "losslessly. See "
#     231         "https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store "
#     232         "for migration guidance. If the filesystem backend is required for your "
#     233         "workflow, set `MLFLOW_ALLOW_FILE_STORE=true` to opt out of this exception.",
#     234         error_code=INVALID_PARAMETER_VALUE,
#     235     )
#     236 self.root_directory = local_file_uri_to_path(root_directory or _default_root_dir())
#     237 if not artifact_root_uri:
#
# MlflowException: The filesystem tracking backend (e.g., './mlruns') is in maintenance mode and will not receive further updates. Please migrate to a database backend (e.g., 'sqlite:///mlflow.db') to access the latest MLflow features. The `mlflow migrate-filestore` tool migrates your existing data losslessly. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance. If the filesystem backend is required for your workflow, set `MLFLOW_ALLOW_FILE_STORE=true` to opt out of this exception.

# %% [markdown]
# ### Creemos un experimento y logguemos la corrida

# %% [markdown]
# Hagamos una prueba con un dataset de juguete.
#
# #### Definición del Experimento
#
# ```python
# mlflow.set_experiment("iris-local-no-server")
# ```
#
# Crea o selecciona un experimento llamado `iris-local-no-server` donde se registrarán todas las ejecuciones relacionadas.
#
# #### Ejecución del Experimento
#
# ```python
# with mlflow.start_run():
#     # Código del experimento
# ```
#
# El contexto `with mlflow.start_run()` inicia automáticamente una nueva ejecución y la finaliza al salir del bloque.

# %% [markdown]
# ## Flujo del Experimento
#
# 1. Carga de Datos
#
# - Utiliza el dataset de iris de scikit-learn como ejemplo.
#
# 2. Definición de Parámetros:
# - C: Parámetro de regularización para LogisticRegression
# - random_state: Semilla para reproducibilidad
#
# - mlflow.log_params() registra estos parámetros para futura referencia
#
# 3. Entrenamiento del Modelo
#
# - Entrena un modelo de regresión logística con los parámetros especificados.
#
# 4. Evaluación y Logging de Métricas
#
# - Calcula predicciones en el conjunto de entrenamiento
# - Registra la métrica de precisión (accuracy) en MLflow
#
# 5. Logging del Modelo
#
# - Guarda el modelo entrenado como un artifact, permitiendo su reutilización posterior.

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score

mlflow.set_experiment("iris-local-no-server")

with mlflow.start_run(run_name="logreg_baseline"):
    X, y = load_iris(return_X_y=True)

    params = {"C": 0.3, "random_state": 42, "max_iter": 200}
    mlflow.log_params(params)

    mlflow.set_tags(
        {
            "scenario": "1_local_file_store",
            "developer": "Maria Durango",
            "module": "mlops_tracking",
            "model_family": "logistic_regression",
            "dataset": "iris",
        }
    )

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)

    mlflow.log_metric("accuracy", float(accuracy_score(y, y_pred)))
    mlflow.log_metric("f1_macro", float(f1_score(y, y_pred, average="macro")))
    mlflow.log_metric("precision_macro", float(precision_score(y, y_pred, average="macro")))

    # Artifact: predicciones
    preds_path = "predictions_logreg.csv"
    pd.DataFrame({"y_true": y, "y_pred": y_pred}).to_csv(preds_path, index=False)
    mlflow.log_artifact(preds_path)

    # Log del modelo (sin registry en este escenario)
    mlflow.sklearn.log_model(lr, name="model", input_example=X[[0]])

    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier

mlflow.set_experiment("iris-local-no-server")

with mlflow.start_run(run_name="rf_baseline"):
    X, y = load_iris(return_X_y=True)

    params = {"n_estimators": 200, "random_state": 42, "n_jobs": -1}
    mlflow.log_params(params)

    mlflow.set_tags(
        {
            "scenario": "1_local_file_store",
            "developer": "Maria Durango",
            "module": "mlops_tracking",
            "model_family": "random_forest",
            "dataset": "iris",
        }
    )

    rf = RandomForestClassifier(**params).fit(X, y)
    y_pred = rf.predict(X)

    mlflow.log_metric("accuracy", float(accuracy_score(y, y_pred)))
    mlflow.log_metric("f1_macro", float(f1_score(y, y_pred, average="macro")))

    preds_path = "predictions_rf.csv"
    pd.DataFrame({"y_true": y, "y_pred": y_pred}).to_csv(preds_path, index=False)
    mlflow.log_artifact(preds_path)

    mlflow.sklearn.log_model(rf, name="model", input_example=X[[0]])

    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")

# %% [markdown]
# ## Exploración de Resultados

# %% [markdown]
# ### Búsqueda de Experimentos
#
# Lista todos los experimentos disponibles en el tracking server.

# %%
mlflow.search_experiments()

# %% [markdown]
# Filtrando por nombre del experimento:

# %%
mlflow.search_experiments(filter_string="name = 'iris-local-no-server'")

# %% [markdown]
# Experiment ID (obtenido desde el nombre):

# %%
experiment = mlflow.get_experiment_by_name("iris-local-no-server")
assert experiment is not None

runs = mlflow.search_runs(
    experiment_ids=[experiment.experiment_id],
    order_by=["metrics.f1_macro DESC"],
)

runs[[
    "run_id",
    "status",
    "metrics.accuracy",
    "metrics.f1_macro",
    "tags.model_family",
    "tags.scenario",
]]

# %%
# Comparación (ordenando por accuracy)

runs = mlflow.search_runs(
    experiment_ids=[experiment.experiment_id],
    order_by=["metrics.accuracy DESC"],
)

runs[[
    "run_id",
    "status",
    "metrics.accuracy",
    "metrics.f1_macro",
    "tags.model_family",
    "tags.scenario",
]]

# %% [markdown]
# ### Interacción con el Model Registry (limitación en este escenario)
#
# En este escenario *no hay tracking server* (solo file store local).
#
# Por eso, el **Model Registry no es el foco** aquí: lo importante es aprender a loggear params/métricas/tags/artifacts.
#
# En escenarios 2 y 3 veremos el Registry en un entorno más parecido a producción (server + backend DB).

# %%
from mlflow.tracking import MlflowClient
from mlflow.exceptions import MlflowException

client = MlflowClient()

try:
    client.search_registered_models()
except MlflowException:
    print("Model Registry no disponible en este escenario (sin tracking server).")
